# %%
import pandas as pd

# %%
#data looks lie table called tabular data
orders= pd.read_table('http://bit.ly/chiporders')

#assumes is tab seperated
#assumes a header

# %%
orders.head()
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# 3                                                NaN     $2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98

# %%
#we need column names for better data interpretation
#create a list of strings with column names and pass it into the pandas read table
user_cols=['user_id','age','gender','occupation','zipcode']

users=pd.read_table('http://bit.ly/movieusers',sep='|', header=None, names=user_cols)

# %%
users.head()
# Out:
#    user_id  age gender  occupation zipcode
# 0        1   24      M  technician   85711
# 1        2   53      F       other   94043
# 2        3   23      M      writer   32067
# 3        4   24      M  technician   43537
# 4        5   33      F       other   15213

# %%
#how do i select a panda series from a dataframe
ufo= pd.read_csv('http://bit.ly/uforeports')
ufo.head()
# Out:
#                    City Colors Reported Shape Reported State             Time
# 0                Ithaca             NaN       TRIANGLE    NY   6/1/1930 22:00
# 1           Willingboro             NaN          OTHER    NJ  6/30/1930 20:00
# 2               Holyoke             NaN           OVAL    CO  2/15/1931 14:00
# 3               Abilene             NaN           DISK    KS   6/1/1931 13:00
# 4  New York Worlds Fair             NaN          LIGHT    NY  4/18/1933 19:00

# %%
type(ufo['City']) 
#alternative is
ufo.City
# Out:
# 0                      Ithaca
# 1                 Willingboro
# 2                     Holyoke
# 3                     Abilene
# 4        New York Worlds Fair
# 5                 Valley City
# 6                 Crater Lake
# 7                        Alma
# 8                     Eklutna
# 9                     Hubbard
# 10                    Fontana
# 11                   Waterloo
# 12                     Belton
# 13                     Keokuk
# 14                  Ludington
# 15                Forest Home
# 16                Los Angeles
# 17                  Hapeville
# 18                     Oneida
# 19                 Bering Sea
# 20                   Nebraska
# 21                        NaN
# 22                        NaN
# 23                  Owensboro
# 24                 Wilderness
# 25                  San Diego
# 26                 Wilderness
# 27                     Clovis
# 28                 Los Alamos
# 29               Ft. Duschene
#                  ...
# ...

# %% [markdown]
# for column names with space in between dot operator doesnt work
# ufo.shape wouldnt work coz shape albready present with pandas

# %%
ufo['Colors Reported']
# Out:
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN
# 5           NaN
# 6           NaN
# 7           NaN
# 8           NaN
# 9           NaN
# 10          NaN
# 11          NaN
# 12          RED
# 13          NaN
# 14          NaN
# 15          NaN
# 16          NaN
# 17          NaN
# 18          NaN
# 19          RED
# 20          NaN
# 21          NaN
# 22          NaN
# 23          NaN
# 24          NaN
# 25          NaN
# 26          NaN
# 27          NaN
# 28          NaN
# 29          NaN
#           ...
# 18211       NaN
# 18212       NaN
# 18213     GREEN
# 18214       NaN
# 18215       NaN
# 18216    ORANGE
# 18217       NaN
# 18218       NaN
# 18219       NaN
# 18220      BLUE
# 18221       NaN
# 18222       NaN
# 18223       NaN
# 18224       NaN
# 18225       NaN
# 18226       NaN
# 18227       NaN
# 18228       NaN
# 18229       NaN
# 18230       NaN
# 18231       NaN
# 18232       NaN
# 18233       RED
# 18234       NaN
# ...

# %%
#string attributes in data frame ca be concatenated
new= ufo.City+ ', '+ ufo.State
new.head()

#to add the concatenated series create a dataframe using only []
ufo['Location'] = ufo.City+ ', '+ ufo.State
ufo.head()
# Out:
#                    City Colors Reported Shape Reported State             Time  \
# 0                Ithaca             NaN       TRIANGLE    NY   6/1/1930 22:00
# 1           Willingboro             NaN          OTHER    NJ  6/30/1930 20:00
# 2               Holyoke             NaN           OVAL    CO  2/15/1931 14:00
# 3               Abilene             NaN           DISK    KS   6/1/1931 13:00
# 4  New York Worlds Fair             NaN          LIGHT    NY  4/18/1933 19:00
#
#                    Location
# 0                Ithaca, NY
# 1           Willingboro, NJ
# 2               Holyoke, CO
# 3               Abilene, KS
# 4  New York Worlds Fair, NY

# %% [markdown]
# # WHY DO SOME PANDAS COMMANDS END WITH PARANTHESES AND OTHER COMMANDS DON'T

# %%
ufo.columns
# Out:
# Index(['City', 'Colors Reported', 'Shape Reported', 'State', 'Time',
#        'Location'],
#       dtype='object')

# %%
#rename columns
ufo.rename(columns={'Colors Reported':'Colors_reported', 'Shape Reported':'Shape_Reported'},inplace=True)
ufo.head()
ufo_cols=['city','colors_reported','shape_reported','state','time','location']
ufo.columns=ufo_cols
ufo.head()
# Out:
#                    city colors_reported shape_reported state             time  \
# 0                Ithaca             NaN       TRIANGLE    NY   6/1/1930 22:00
# 1           Willingboro             NaN          OTHER    NJ  6/30/1930 20:00
# 2               Holyoke             NaN           OVAL    CO  2/15/1931 14:00
# 3               Abilene             NaN           DISK    KS   6/1/1931 13:00
# 4  New York Worlds Fair             NaN          LIGHT    NY  4/18/1933 19:00
#
#                    location
# 0                Ithaca, NY
# 1           Willingboro, NJ
# 2               Holyoke, CO
# 3               Abilene, KS
# 4  New York Worlds Fair, NY

# %%
movies= pd.read_csv('http://bit.ly/imdbratings')
movies.head()
movies.describe() #shows descriptive stats
# Out:
#        star_rating    duration
# count   979.000000  979.000000
# mean      7.889785  120.979571
# std       0.336069   26.218010
# min       7.400000   64.000000
# 25%       7.600000  102.000000
# 50%       7.800000  117.000000
# 75%       8.100000  134.000000
# max       9.300000  242.000000

# %%
movies.shape
# Out:
# (979, 6)

# %%
type(movies.dtypes)
# Out:
# pandas.core.series.Series

# %%
#methods as action oriented eg talk, eat, walk
#attributes of who you are height,age, city
movies.describe(include=['object']) 
#for jupyter ntbook anywhere a parathenses shift+tab to check describtion
# Out:
#                                   title content_rating  genre  \
# count                               979            976    979
# unique                              975             12     16
# top     The Girl with the Dragon Tattoo              R  Drama
# freq                                  2            460    278
#
#                                               actors_list
# count                                                 979
# unique                                                969
# top     [u'Daniel Radcliffe', u'Emma Watson', u'Rupert...
# freq                                                    6

# %%
ufo.head()
# Out:
#                    city colors_reported shape_reported state             time  \
# 0                Ithaca             NaN       TRIANGLE    NY   6/1/1930 22:00
# 1           Willingboro             NaN          OTHER    NJ  6/30/1930 20:00
# 2               Holyoke             NaN           OVAL    CO  2/15/1931 14:00
# 3               Abilene             NaN           DISK    KS   6/1/1931 13:00
# 4  New York Worlds Fair             NaN          LIGHT    NY  4/18/1933 19:00
#
#                    location
# 0                Ithaca, NY
# 1           Willingboro, NJ
# 2               Holyoke, CO
# 3               Abilene, KS
# 4  New York Worlds Fair, NY

# %%
ufo.columns = ufo.columns.str.upper().str.replace(' ', '_')
ufo.columns
# Out:
# Index(['CITY', 'COLORS_REPORTED', 'SHAPE_REPORTED', 'STATE', 'TIME',
#        'LOCATION'],
#       dtype='object')

# %% [markdown]
# # HOW DO I REMOVE COLUMNS FROM PANDAS DATAFRAME

# %%
ufo=pd.read_csv('http://bit.ly/uforeports')
ufo.head()
# Out:
#                    City Colors Reported Shape Reported State             Time
# 0                Ithaca             NaN       TRIANGLE    NY   6/1/1930 22:00
# 1           Willingboro             NaN          OTHER    NJ  6/30/1930 20:00
# 2               Holyoke             NaN           OVAL    CO  2/15/1931 14:00
# 3               Abilene             NaN           DISK    KS   6/1/1931 13:00
# 4  New York Worlds Fair             NaN          LIGHT    NY  4/18/1933 19:00

# %%
#drop method
ufo.drop('Colors Reported',axis=1, inplace=True) #i want to drop column said by axis 
ufo.head()
# Out:
#                    City Shape Reported State             Time
# 0                Ithaca       TRIANGLE    NY   6/1/1930 22:00
# 1           Willingboro          OTHER    NJ  6/30/1930 20:00
# 2               Holyoke           OVAL    CO  2/15/1931 14:00
# 3               Abilene           DISK    KS   6/1/1931 13:00
# 4  New York Worlds Fair          LIGHT    NY  4/18/1933 19:00

# %%
#drop multiple columns
ufo.drop(['City','State'],axis=1,inplace=True)
ufo.head()
# Out:
#   Shape Reported             Time
# 0       TRIANGLE   6/1/1930 22:00
# 1          OTHER  6/30/1930 20:00
# 2           OVAL  2/15/1931 14:00
# 3           DISK   6/1/1931 13:00
# 4          LIGHT  4/18/1933 19:00

# %% [markdown]
# # HOW DO I SORT  PANAS DATAFRAME OR SERIES

# %%
import pandas as pd
movies=pd.read_csv('http://bit.ly/imdbratings')
movies.head()
# Out:
#    star_rating                     title content_rating   genre  duration  \
# 0          9.3  The Shawshank Redemption              R   Crime       142
# 1          9.2             The Godfather              R   Crime       175
# 2          9.1    The Godfather: Part II              R   Crime       200
# 3          9.0           The Dark Knight          PG-13  Action       152
# 4          8.9              Pulp Fiction              R   Crime       154
#
#                                          actors_list
# 0  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1    [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 3  [u'Christian Bale', u'Heath Ledger', u'Aaron E...
# 4  [u'John Travolta', u'Uma Thurman', u'Samuel L....

# %%
movies.title.sort_values()  #both works the same #ascending order default
movies['title'].sort_values()
#series sorting order
type(movies.title.sort_values(ascending=False) )#original order of data remains same
# Out:
# pandas.core.series.Series

# %%
movies.sort_values('title',ascending=False) #dataframe sorting
movies.sort_values(['duration','content_rating'])

#sort dataset by taking 2 columns 
#first the dataset will be sorted with the first mentioned column name then by the second
# Out:
#      star_rating                                          title  \
# 389          8.0                                         Freaks
# 338          8.0                            Battleship Potemkin
# 258          8.1                    The Cabinet of Dr. Caligari
# 88           8.4                                        The Kid
# 293          8.1                                      Duck Soup
# 742          7.6                                      Following
# 351          8.0                                   Frankenstein
# 938          7.4                            Alice in Wonderland
# 405          7.9                      The Bride of Frankenstein
# 303          8.0                 The Nightmare Before Christmas
# 713          7.6                                The Jungle Book
# 489          7.8                     The Triplets of Belleville
# 864          7.5                                          [Rec]
# 535          7.8                                          Zelig
# ...

# %% [markdown]
# # FILTER ROWS BY COLUMN VALUE

# %%
movies.shape
# Out:
# (979, 6)

# %%
is_long=movies.duration>=200 #one line instead of loops
is_long.head()
#here the movies.duration is creating a series of booleans with
movies[movies.duration>=200]
# Out:
# 0    False
# 1    False
# 2     True
# 3    False
# 4    False
# Name: duration, dtype: bool

# %%
#python list of bool which row match the condition
#working of  the operator df.col_name>=value
booleans=[]
for duration in movies.duration:
    if duration>=200:
        booleans.append(True)
    else:
        booleans.append(False)
booleans[0:5]
len(booleans)
# Out:
# 979

# %%
#convert list into pd series
is_long=pd.Series(booleans)
is_long.head()
movies[is_long] #showing dataframe all columns with duration is 200mins
# Out:
#      star_rating                                          title  \
# 2            9.1                         The Godfather: Part II
# 7            8.9  The Lord of the Rings: The Return of the King
# 17           8.7                                  Seven Samurai
# 78           8.4                    Once Upon a Time in America
# 85           8.4                             Lawrence of Arabia
# 142          8.3              Lagaan: Once Upon a Time in India
# 157          8.2                             Gone with the Wind
# 204          8.1                                        Ben-Hur
# 445          7.9                           The Ten Commandments
# 476          7.8                                         Hamlet
# 630          7.7                                      Malcolm X
# 767          7.6                It's a Mad, Mad, Mad, Mad World
#
#     content_rating      genre  duration  \
# 2                R      Crime       200
# 7            PG-13  Adventure       201
# ...

# %%
movies.loc[movies.duration>=200 , 'genre']
# Out:
# 2          Crime
# 7      Adventure
# 17         Drama
# 78         Crime
# 85     Adventure
# 142    Adventure
# 157        Drama
# 204    Adventure
# 445    Adventure
# 476        Drama
# 630    Biography
# 767       Action
# Name: genre, dtype: object

# %%
movies[ (movies.genre=='Action') | (movies.genre=='Drama')]
#alternate method
movies.genre.isin(['Crime', 'Adventure','Action'])
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
# 5      False
# 6      False
# 7       True
# 8      False
# 9      False
# 10      True
# 11      True
# 12      True
# 13     False
# 14      True
# 15      True
# 16     False
# 17     False
# 18     False
# 19      True
# 20      True
# 21      True
# 22     False
# 23      True
# 24     False
# 25     False
# 26     False
# 27     False
# 28      True
# 29     False
#        ...
# 949    False
# 950     True
# 951    False
# 952    False
# 953     True
# 954     True
# 955    False
# 956    False
# 957    False
# 958    False
# 959    False
# 960    False
# 961    False
# 962    False
# 963     True
# 964    False
# 965    False
# 966    False
# 967     True
# 968    False
# 969     True
# 970    False
# 971    False
# 972    False
# 973    False
# 974    False
# 975     True
# 976     True
# 977    False
# 978     True
# Name: genre, Length: 979, dtype: bool

# %%
movies[(movies.duration>=200) | (movies.genre=='Drama')]
# Out:
#      star_rating                                           title  \
# 2            9.1                          The Godfather: Part II
# 5            8.9                                    12 Angry Men
# 7            8.9   The Lord of the Rings: The Return of the King
# 9            8.9                                      Fight Club
# 13           8.8                                    Forrest Gump
# 16           8.7                 One Flew Over the Cuckoo's Nest
# 17           8.7                                   Seven Samurai
# 22           8.7                           It's a Wonderful Life
# 24           8.7                                           Se7en
# 27           8.6                        The Silence of the Lambs
# 32           8.6                                      Casablanca
# 33           8.6                                        Whiplash
# 41           8.5                                    Sunset Blvd.
# ...

# %%
#qna from comments
#1. read from csv only 2 columns and remove others
import pandas as pd
ufo=pd.read_csv('http://bit.ly/uforeports', usecols=[0,4]) #or
ufo=pd.read_csv('http://bit.ly/uforeports')
ufo.columns
# Out:
# Index(['City'], dtype='object')

# %%
#fastest way to read  csv files
ufo#only for dataframes for series another built in method
ufo=pd.read_csv('http://bit.ly/uforeports', nrows=3)
for c in ufo.City:
    print(c)
    
#only for dataframes for series another built in method
for index,row in ufo.iterrows():
    print(index,row.City,row.State)
# Out:
# Ithaca
# Willingboro
# Holyoke
# 0 Ithaca NY
# 1 Willingboro NJ
# 2 Holyoke CO

# %%
drinks=pd.read_csv('http://bit.ly/drinksbycountry')
drinks.dtypes
import numpy as np
drinks.select_dtypes(include=[np.number]).dtypes
drinks.describe() #describe numeric columns only
#but if we want all columns
drinks.describe(include='all')
# Out:
#          country  beer_servings  spirit_servings  wine_servings  \
# count        193     193.000000       193.000000     193.000000
# unique       193            NaN              NaN            NaN
# top     Djibouti            NaN              NaN            NaN
# freq           1            NaN              NaN            NaN
# mean         NaN     106.160622        80.994819      49.450777
# std          NaN     101.143103        88.284312      79.697598
# min          NaN       0.000000         0.000000       0.000000
# 25%          NaN      20.000000         4.000000       1.000000
# 50%          NaN      76.000000        56.000000       8.000000
# 75%          NaN     188.000000       128.000000      59.000000
# max          NaN     376.000000       438.000000     370.000000
#
#         total_litres_of_pure_alcohol continent
# count                     193.000000       193
# unique                           NaN         6
# top                              NaN    Africa
# ...

# %%
drinks.head()
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# 0  Afghanistan              0                0              0
# 1      Albania             89              132             54
# 2      Algeria             25                0             14
# 3      Andorra            245              138            312
# 4       Angola            217               57             45
#
#    total_litres_of_pure_alcohol continent
# 0                           0.0      Asia
# 1                           4.9    Europe
# 2                           0.7    Africa
# 3                          12.4    Europe
# 4                           5.9    Africa

# %%
drinks.drop('continent', axis=1).head()
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# 0  Afghanistan              0                0              0
# 1      Albania             89              132             54
# 2      Algeria             25                0             14
# 3      Andorra            245              138            312
# 4       Angola            217               57             45
#
#    total_litres_of_pure_alcohol
# 0                           0.0
# 1                           4.9
# 2                           0.7
# 3                          12.4
# 4                           5.9

# %%
drinks.drop(2, axis=0).head()
# Out:
#              country  beer_servings  spirit_servings  wine_servings  \
# 0        Afghanistan              0                0              0
# 1            Albania             89              132             54
# 3            Andorra            245              138            312
# 4             Angola            217               57             45
# 5  Antigua & Barbuda            102              128             45
#
#    total_litres_of_pure_alcohol      continent
# 0                           0.0           Asia
# 1                           4.9         Europe
# 3                          12.4         Europe
# 4                           5.9         Africa
# 5                           4.9  North America

# %%
drinks.mean(axis=0) #of only numeric columns only of series 
#default behavior axis=0
#Axis 0 will act on all the ROWS in each COLUMN
#Axis 1 will act on all the COLUMNS in each ROW
#So a mean on axis 0 will be the mean of all the rows in each column, and a mean on axis 1 will be a mean of all the columns in each row
# Out:
# beer_servings                   106.160622
# spirit_servings                  80.994819
# wine_servings                    49.450777
# total_litres_of_pure_alcohol      4.717098
# dtype: float64

# %%
'hello'.lower()
# Out:
# 'hello'

# %%
import pandas as pd
orders=pd.read_table('http://bit.ly/chiporders')

# %%
orders.head()
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# 3                                                NaN     $2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98

# %%
orders.item_name.str.upper()
# Out:
# 0                CHIPS AND FRESH TOMATO SALSA
# 1                                        IZZE
# 2                            NANTUCKET NECTAR
# 3       CHIPS AND TOMATILLO-GREEN CHILI SALSA
# 4                                CHICKEN BOWL
# 5                                CHICKEN BOWL
# 6                               SIDE OF CHIPS
# 7                               STEAK BURRITO
# 8                            STEAK SOFT TACOS
# 9                               STEAK BURRITO
# 10                        CHIPS AND GUACAMOLE
# 11                       CHICKEN CRISPY TACOS
# 12                         CHICKEN SOFT TACOS
# 13                               CHICKEN BOWL
# 14                        CHIPS AND GUACAMOLE
# 15      CHIPS AND TOMATILLO-GREEN CHILI SALSA
# 16                            CHICKEN BURRITO
# 17                            CHICKEN BURRITO
# 18                                CANNED SODA
# 19                               CHICKEN BOWL
# ...

# %%
orders.item_name.str.contains('Chicken') #to filter dataframe
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4        True
# 5        True
# 6       False
# 7       False
# 8       False
# 9       False
# 10      False
# 11       True
# 12       True
# 13       True
# 14      False
# 15      False
# 16       True
# 17       True
# 18      False
# 19       True
# 20      False
# 21      False
# 22      False
# 23       True
# 24      False
# 25      False
# 26       True
# 27      False
# 28      False
# 29       True
#         ...
# 4592    False
# 4593    False
# 4594    False
# 4595     True
# 4596    False
# 4597    False
# 4598    False
# 4599     True
# 4600    False
# 4601    False
# 4602    False
# 4603    False
# 4604     True
# 4605    False
# 4606    False
# 4607    False
# 4608    False
# 4609    False
# 4610    False
# 4611    False
# 4612    False
# 4613    False
# 4614    False
# 4615     True
# 4616    False
# 4617    False
# 4618    False
# 4619     True
# 4620     True
# 4621     True
# ...

# %%
orders.choice_description.str.replace('[','').str.replace(']','')
# Out:
# 0                                                     NaN
# 1                                              Clementine
# 2                                                   Apple
# 3                                                     NaN
# 4       Tomatillo-Red Chili Salsa (Hot), Black Beans, ...
# 5       Fresh Tomato Salsa (Mild), Rice, Cheese, Sour ...
# 6                                                     NaN
# 7       Tomatillo Red Chili Salsa, Fajita Vegetables, ...
# 8       Tomatillo Green Chili Salsa, Pinto Beans, Chee...
# 9       Fresh Tomato Salsa, Rice, Black Beans, Pinto B...
# 10                                                    NaN
# 11      Roasted Chili Corn Salsa, Fajita Vegetables, R...
# 12      Roasted Chili Corn Salsa, Rice, Black Beans, C...
# 13      Fresh Tomato Salsa, Fajita Vegetables, Rice, C...
# 14                                                    NaN
# 15                                                    NaN
# ...

# %%
orders.choice_description.str.replace('[\[\]]','')
# Out:
# 0                                                     NaN
# 1                                              Clementine
# 2                                                   Apple
# 3                                                     NaN
# 4       Tomatillo-Red Chili Salsa (Hot), Black Beans, ...
# 5       Fresh Tomato Salsa (Mild), Rice, Cheese, Sour ...
# 6                                                     NaN
# 7       Tomatillo Red Chili Salsa, Fajita Vegetables, ...
# 8       Tomatillo Green Chili Salsa, Pinto Beans, Chee...
# 9       Fresh Tomato Salsa, Rice, Black Beans, Pinto B...
# 10                                                    NaN
# 11      Roasted Chili Corn Salsa, Fajita Vegetables, R...
# 12      Roasted Chili Corn Salsa, Rice, Black Beans, C...
# 13      Fresh Tomato Salsa, Fajita Vegetables, Rice, C...
# 14                                                    NaN
# 15                                                    NaN
# ...

# %% [markdown]
# # how do i change the data type of a pandas series

# %%
import pandas as pd
drinks=pd.read_csv('http://bit.ly/drinksbycountry')
drinks.head()
drinks.dtypes
# Out:
# country                          object
# beer_servings                     int64
# spirit_servings                   int64
# wine_servings                     int64
# total_litres_of_pure_alcohol    float64
# continent                        object
# dtype: object

# %%
drinks['beer_servings']=drinks.beer_servings.astype(float)
drinks.dtypes #if str and do math on column
# Out:
# country                          object
# beer_servings                   float64
# spirit_servings                   int64
# wine_servings                     int64
# total_litres_of_pure_alcohol    float64
# continent                        object
# dtype: object

# %%
drinks=pd.read_csv('http://bit.ly/drinksbycountry', dtype={'beer_servings':float})
drinks.dtypes
# Out:
# country                          object
# beer_servings                   float64
# spirit_servings                   int64
# wine_servings                     int64
# total_litres_of_pure_alcohol    float64
# continent                        object
# dtype: object

# %%
orders.item_price.str.replace('$','').astype(float).mean()
orders.head()
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# 3                                                NaN     $2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98

# %% [markdown]
# # if you want to give item_name as an i/p it should be numeric so to conver the i/p feature in 1/0 we can
# orders.item_name.str.contains('Chicken').astype(int).head()

# %% [markdown]
# # when to use a groupby in pandas
# anytime we want to analyze series by cateogary
# for each candiate good for groupy

# %%
import pandas as pd
drinks= pd.read_csv("http://bit.ly/drinksbycountry")
drinks.head()
drinks[drinks.continent=='Africa'].beer_servings.mean()
# Out:
# 61.471698113207545

# %%
***************************************#imp
drinks.groupby('continent').beer_servings.agg(['count','min','max','mean'])
# Out:
#                count  min  max        mean
# continent
# Africa            53    0  376   61.471698
# Asia              44    0  247   37.045455
# Europe            45    0  361  193.777778
# North America     23    1  285  145.434783
# Oceania           16    0  306   89.687500
# South America     12   93  333  175.083333

# %%
#bonus tip
drinks.groupby('continent').agg(['count','min','max','mean'])
#gives the mean of all numeric columns without defining it
# Out:
#               beer_servings                      spirit_servings           \
#                       count min  max        mean           count min  max
# continent
# Africa                   53   0  376   61.471698              53   0  152
# Asia                     44   0  247   37.045455              44   0  326
# Europe                   45   0  361  193.777778              45   0  373
# North America            23   1  285  145.434783              23  68  438
# Oceania                  16   0  306   89.687500              16   0  254
# South America            12  93  333  175.083333              12  25  302
#
#                           wine_servings                       \
#                      mean         count min  max        mean
# continent
# Africa          16.339623            53   0  233   16.264151
# Asia            60.840909            44   0  123    9.068182
# Europe         132.555556            45   0  370  142.222222
# ...

# %%
# %matplotlib inline
drinks.groupby('continent').agg(['mean']).plot(kind='bar')

# %% [markdown]
# # how to explore pandas series

# %%
import pandas as pd
movies=pd.read_csv("http://bit.ly/imdbratings")
movies.head()
# Out:
#    star_rating                     title content_rating   genre  duration  \
# 0          9.3  The Shawshank Redemption              R   Crime       142
# 1          9.2             The Godfather              R   Crime       175
# 2          9.1    The Godfather: Part II              R   Crime       200
# 3          9.0           The Dark Knight          PG-13  Action       152
# 4          8.9              Pulp Fiction              R   Crime       154
#
#                                          actors_list
# 0  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1    [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 3  [u'Christian Bale', u'Heath Ledger', u'Aaron E...
# 4  [u'John Travolta', u'Uma Thurman', u'Samuel L....

# %%
movies.dtypes
# Out:
# star_rating       float64
# title              object
# content_rating     object
# genre              object
# duration            int64
# actors_list        object
# dtype: object

# %%
movies.genre.describe()
# Out:
# count       979
# unique       16
# top       Drama
# freq        278
# Name: genre, dtype: object

# %%
movies.genre.value_counts(normalize=True).head() #converts into %
# Out:
# Drama        0.283963
# Comedy       0.159346
# Action       0.138917
# Crime        0.126660
# Biography    0.078652
# Name: genre, dtype: float64

# %%
movies.genre.unique()
movies.genre.nunique()
# Out:
# 16

# %%
pd.crosstab(movies.genre, movies.content_rating)
# Out:
# content_rating  APPROVED   G  GP  NC-17  NOT RATED  PASSED  PG  PG-13    R  \
# genre
# Action                 3   1   1      0          4       1  11     44   67
# Adventure              3   2   0      0          5       1  21     23   17
# Animation              3  20   0      0          3       0  25      5    5
# Biography              1   2   1      0          1       0   6     29   36
# Comedy                 9   2   1      1         16       3  23     23   73
# Crime                  6   0   0      1          7       1   6      4   87
# Drama                 12   3   0      4         24       1  25     55  143
# Family                 0   1   0      0          0       0   1      0    0
# Fantasy                0   0   0      0          0       0   0      0    1
# Film-Noir              1   0   0      0          1       0   0      0    0
# History                0   0   0      0          0       0   0      0    0
# ...

# %%
movies.duration.describe() #use to see some stats value
# Out:
# count    979.000000
# mean     120.979571
# std       26.218010
# min       64.000000
# 25%      102.000000
# 50%      117.000000
# 75%      134.000000
# max      242.000000
# Name: duration, dtype: float64

# %%
#bonus tip
# %matplotlib inline
movies.duration.plot(kind='hist')

# %%
movies.genre.value_counts().plot(kind='bar')

# %%
import pandas as pd
ufo=pd.read_csv("http://bit.ly/uforeports")
ufo.tail()
# Out:
#               City Colors Reported Shape Reported State              Time
# 18236   Grant Park             NaN       TRIANGLE    IL  12/31/2000 23:00
# 18237  Spirit Lake             NaN           DISK    IA  12/31/2000 23:00
# 18238  Eagle River             NaN            NaN    WI  12/31/2000 23:45
# 18239  Eagle River             RED          LIGHT    WI  12/31/2000 23:45
# 18240         Ybor             NaN           OVAL    FL  12/31/2000 23:59

# %%
#nan means missing
#method for working with missing values
ufo.isnull().tail()
#false means not missing
#true means missing
#trick 
ufo.isnull().sum()
#s0 the isnull is converting the values in boolean i.e true or false and then sum is doin vertical stack on each column
#how does it works
# Out:
# City                  25
# Colors Reported    15359
# Shape Reported      2644
# State                  0
# Time                   0
# dtype: int64

# %%
#eg
pd.Series([True,False,True]).sum() #show number of true at column level
# Out:
# 2

# %%
ufo[ufo.City.isnull()] #SUBSET OF DATAFRAME WHERE DATA IS MISSING
# Out:
#       City Colors Reported Shape Reported State              Time
# 21     NaN             NaN            NaN    LA    8/15/1943 0:00
# 22     NaN             NaN          LIGHT    LA    8/15/1943 0:00
# 204    NaN             NaN           DISK    CA   7/15/1952 12:30
# 241    NaN            BLUE           DISK    MT    7/4/1953 14:00
# 613    NaN             NaN           DISK    NV    7/1/1960 12:00
# 1877   NaN          YELLOW         CIRCLE    AZ    8/15/1969 1:00
# 2013   NaN             NaN            NaN    NH     8/1/1970 9:30
# 2546   NaN             NaN       FIREBALL    OH  10/25/1973 23:30
# 3123   NaN             RED       TRIANGLE    WV  11/25/1975 23:00
# 4736   NaN             NaN         SPHERE    CA   6/23/1982 23:00
# 5269   NaN             NaN            NaN    AZ   6/30/1985 21:30
# 6735   NaN             NaN      FORMATION    TX     4/1/1992 2:00
# 7208   NaN             NaN         CIRCLE    MI   10/4/1993 17:30
# ...

# %%
#OPTIONS HOW TO HANDLE THE MISSING
#DROP
ufo.shape
#1
ufo.dropna(how='any').shape
#->drop a row if any of its value are missing
#by default inplace is false as it temporarily drops it
# Out:
# (2486, 5)

# %%
ufo.dropna(how='all').shape
#->drop a row if all of its value are missing
ufo.dropna(subset=['City','Shape Reported'], how='all').shape
# Out:
# (18237, 5)

# %%
#filling missing value
ufo['Shape Reported'].value_counts() #missing values are excluded

#lets add those missing values too
ufo['Shape Reported'].value_counts(dropna=False)
#Nan 2644 so we might club these values with some other not so important depending
#upon the data in this datset we can club with  VARIOUS 333

ufo['Shape Reported'].fillna(value='VARIOUS',inplace=True)
ufo['Shape Reported'].value_counts()
# Out:
# VARIOUS      2977
# LIGHT        2803
# DISK         2122
# TRIANGLE     1889
# OTHER        1402
# CIRCLE       1365
# SPHERE       1054
# FIREBALL     1039
# OVAL          845
# CIGAR         617
# FORMATION     434
# RECTANGLE     303
# CYLINDER      294
# CHEVRON       248
# DIAMOND       234
# EGG           197
# FLASH         188
# TEARDROP      119
# CONE           60
# CROSS          36
# DELTA           7
# CRESCENT        2
# ROUND           2
# DOME            1
# HEXAGON         1
# PYRAMID         1
# FLARE           1
# Name: Shape Reported, dtype: int64

# %%
import pandas as pd
drinks= pd.read_csv("http://bit.ly/drinksbycountry")
drinks.head()
#drinks.index #row labels the index
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# 0  Afghanistan              0                0              0
# 1      Albania             89              132             54
# 2      Algeria             25                0             14
# 3      Andorra            245              138            312
# 4       Angola            217               57             45
#
#    total_litres_of_pure_alcohol continent
# 0                           0.0      Asia
# 1                           4.9    Europe
# 2                           0.7    Africa
# 3                          12.4    Europe
# 4                           5.9    Africa

# %%
drinks.columns
# Out:
# Index(['country', 'beer_servings', 'spirit_servings', 'wine_servings',
#        'total_litres_of_pure_alcohol', 'continent'],
#       dtype='object')

# %%
#why we use indexing
#identificaton
#selection
#alignment
drinks[drinks.continent=='South America']
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# 6    Argentina            193               25            221
# 20     Bolivia            167               41              8
# 23      Brazil            245              145             16
# 35       Chile            130              124            172
# 37    Colombia            159               76              3
# 52     Ecuador            162               74              3
# 72      Guyana             93              302              1
# 132   Paraguay            213              117             74
# 133       Peru            163              160             21
# 163   Suriname            128              178              7
# 185    Uruguay            115               35            220
# 188  Venezuela            333              100              3
#
#      total_litres_of_pure_alcohol      continent
# 6                             8.3  South America
# 20                            3.8  South America
# ...

# %%
#drinks.loc[23,'beer_servings']
drinks.ix[1, 'beer_servings']
# Out:
# C:\Users\Himanshu\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
# 89

# %%
drinks.continent.head()
# Out:
# country
# Afghanistan      Asia
# Albania        Europe
# Algeria        Africa
# Andorra        Europe
# Angola         Africa
# Name: continent, dtype: object

# %% [markdown]
# #### drinks.set_index('country')

# %%
drinks.country.value_counts().sort_index()#series
# Out:
# Afghanistan             1
# Albania                 1
# Algeria                 1
# Andorra                 1
# Angola                  1
# Antigua & Barbuda       1
# Argentina               1
# Armenia                 1
# Australia               1
# Austria                 1
# Azerbaijan              1
# Bahamas                 1
# Bahrain                 1
# Bangladesh              1
# Barbados                1
# Belarus                 1
# Belgium                 1
# Belize                  1
# Benin                   1
# Bhutan                  1
# Bolivia                 1
# Bosnia-Herzegovina      1
# Botswana                1
# Brazil                  1
# Brunei                  1
# Bulgaria                1
# Burkina Faso            1
# Burundi                 1
# Cabo Verde              1
# Cambodia                1
#                        ..
# Sudan                   1
# Suriname                1
# Swaziland               1
# Sweden                  1
# ...

# %%
people = pd.Series([300000,85000] , index = ['Albania' , 'Andorra'] , name = 'population')
drinks.beer_servings*people
pd.concat([drinks,people], axis=1).head()
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# 0  Afghanistan            0.0              0.0            0.0
# 1      Albania           89.0            132.0           54.0
# 2      Algeria           25.0              0.0           14.0
# 3      Andorra          245.0            138.0          312.0
# 4       Angola          217.0             57.0           45.0
#
#    total_litres_of_pure_alcohol continent  population
# 0                           0.0      Asia         NaN
# 1                           4.9    Europe         NaN
# 2                           0.7    Africa         NaN
# 3                          12.4    Europe         NaN
# 4                           5.9    Africa         NaN

# %% [markdown]
# # how do i select multiple rows and columns froma pandas dataframe

# %%
import pandas as pd
ufo = pd.read_csv('http://bit.ly/uforeports', sep=',' )
ufo.head()
# Out:
#                    City Colors Reported Shape Reported State             Time
# 0                Ithaca             NaN       TRIANGLE    NY   6/1/1930 22:00
# 1           Willingboro             NaN          OTHER    NJ  6/30/1930 20:00
# 2               Holyoke             NaN           OVAL    CO  2/15/1931 14:00
# 3               Abilene             NaN           DISK    KS   6/1/1931 13:00
# 4  New York Worlds Fair             NaN          LIGHT    NY  4/18/1933 19:00

# %%
#filtering rows and columns by label ie column use bracket not paranthesis
ufo.loc[0, :]
#colon means all columns
#multiple rows
ufo.loc[[0,1,2], :]
# Out:
#           City Colors Reported Shape Reported State             Time
# 0       Ithaca             NaN       TRIANGLE    NY   6/1/1930 22:00
# 1  Willingboro             NaN          OTHER    NJ  6/30/1930 20:00
# 2      Holyoke             NaN           OVAL    CO  2/15/1931 14:00

# %%
ufo.loc[0:2,:]
# Out:
#           City Colors Reported Shape Reported State             Time
# 0       Ithaca             NaN       TRIANGLE    NY   6/1/1930 22:00
# 1  Willingboro             NaN          OTHER    NJ  6/30/1930 20:00
# 2      Holyoke             NaN           OVAL    CO  2/15/1931 14:00

# %%
ufo.loc[:,['City','State']]
# Out:
#                        City State
# 0                    Ithaca    NY
# 1               Willingboro    NJ
# 2                   Holyoke    CO
# 3                   Abilene    KS
# 4      New York Worlds Fair    NY
# 5               Valley City    ND
# 6               Crater Lake    CA
# 7                      Alma    MI
# 8                   Eklutna    AK
# 9                   Hubbard    OR
# 10                  Fontana    CA
# 11                 Waterloo    AL
# 12                   Belton    SC
# 13                   Keokuk    IA
# 14                Ludington    MI
# 15              Forest Home    CA
# 16              Los Angeles    CA
# 17                Hapeville    GA
# 18                   Oneida    TN
# 19               Bering Sea    AK
# 20                 Nebraska    NE
# 21                      NaN    LA
# 22                      NaN    LA
# 23                Owensboro    KY
# 24               Wilderness    WV
# 25                San Diego    CA
# ...

# %%
ufo.loc[0:2 ,['City','State']]
# Out:
#           City State
# 0       Ithaca    NY
# 1  Willingboro    NJ
# 2      Holyoke    CO

# %%
ufo.head(3).drop('Time', axis=1)
# Out:
#           City Colors Reported Shape Reported State
# 0       Ithaca             NaN       TRIANGLE    NY
# 1  Willingboro             NaN          OTHER    NJ
# 2      Holyoke             NaN           OVAL    CO

# %%
ufo[ufo.City=='Oakland'].State #chain indexing cause problem in future,2 operations
#alternate using loc is
ufo.loc[ufo.City=='Oakland','State'] #one internal operation
# Out:
# 1694     CA
# 2144     CA
# 4686     MD
# 7293     CA
# 8488     CA
# 8768     CA
# 10816    OR
# 10948    CA
# 11045    CA
# 12322    CA
# 12941    CA
# 16803    MD
# 17322    CA
# Name: State, dtype: object

# %%
#ufo.loc[:, 0:4] #will give error
#ufo.iloc[:,0:4] #works like range inclusive to both sides

ufo.iloc[0:3,:]
# Out:
#           City Colors Reported Shape Reported State             Time
# 0       Ithaca             NaN       TRIANGLE    NY   6/1/1930 22:00
# 1  Willingboro             NaN          OTHER    NJ  6/30/1930 20:00
# 2      Holyoke             NaN           OVAL    CO  2/15/1931 14:00

# %%
ufo.loc[0:3,:] #includes 3 row
# Out:
#           City Colors Reported Shape Reported State             Time
# 0       Ithaca             NaN       TRIANGLE    NY   6/1/1930 22:00
# 1  Willingboro             NaN          OTHER    NJ  6/30/1930 20:00
# 2      Holyoke             NaN           OVAL    CO  2/15/1931 14:00
# 3      Abilene             NaN           DISK    KS   6/1/1931 13:00

# %%
#shortcuts

ufo[['City','State']] #list of strings selec that columns
ufo[0:2] #refering to rows by integer position
# Out:
#           City Colors Reported Shape Reported State             Time
# 0       Ithaca             NaN       TRIANGLE    NY   6/1/1930 22:00
# 1  Willingboro             NaN          OTHER    NJ  6/30/1930 20:00

# %% [markdown]
# # when to use inplace parameter in pandas

# %%
ufo.drop('City', axis=1, inplace=True)

# %%
ufo.head()
# Out:
#   Colors Reported Shape Reported State             Time
# 0             NaN       TRIANGLE    NY   6/1/1930 22:00
# 1             NaN          OTHER    NJ  6/30/1930 20:00
# 2             NaN           OVAL    CO  2/15/1931 14:00
# 3             NaN           DISK    KS   6/1/1931 13:00
# 4             NaN          LIGHT    NY  4/18/1933 19:00
